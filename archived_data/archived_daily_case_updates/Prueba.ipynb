# %%
from os import scandir, getcwd
import pandas as pd
import numpy as np

def ls(ruta = getcwd()):
    return [arch.name for arch in scandir(ruta) if arch.is_file()]

# %%
def soloCSV():
    salida = []
    for i in ls():
        largo = len(i)
        if("csv" == i[ largo - 3 : largo]):
            salida.append(i)
            print(i)
    return salida

def DataUnida():
    salida = []
    for i in soloCSV():
        data_aux = pd.read_csv(i)
        print(len(data_aux))
        salida.append(data_aux)
    return pd.concat(salida)

# %%
#soloCSV()
data = DataUnida()
data
# Out:
# 01-21-2020_2200.csv
# 01-22-2020_1200.csv
# 01-23-2020_1200.csv
# 01-24-2020_0000.csv
# 01-24-2020_1200.csv
# 01-25-2020_0000.csv
# 01-25-2020_1200.csv
# 01-25-2020_2200.csv
# 01-26-2020_1100.csv
# 01-26-2020_2300.csv
# 01-27-2020_0900.csv
# 01-27-2020_1900.csv
# 01-27-2020_2030.csv
# 01-28-2020_1300.csv
# 01-28-2020_1800.csv
# 01-28-2020_2300.csv
# 01-29-2020_1330.csv
# 01-29-2020_1430.csv
# 01-29-2020_2100.csv
# 01-30-2020_1100.csv
# 01-30-2020_2130.csv
# 01-31-2020_1400.csv
# 02-01-2020_1000.csv
# 02-01-2020_1800.csv
# 02-01-2020_2300.csv
# 02-02-2020_0500.csv
# 02-02-2020_1945.csv
# 02-02-2020_2100.csv
# 02-03-2020_1230.csv
# 02-03-2020_2140.csv
# 02-04-2020_0800.csv
# 02-04-2020_1150.csv
# 02-04-2020_2200.csv
# 02-05-2020_1220.csv
# 02-06-2020_1318.csv
# 02-06-2020_2005.csv
# 02-07-2020_2024.csv
# 02-08-2020_1024.csv
# 02-08-2020_2304.csv
# 02-09-2020_1030.csv
# 02-09-2020_2320.csv
# 02-10-2020_1030.csv
# 02-10-2020_1930.csv
# 02-11-2020_1050.csv
# 02-11-2020_2044.csv
# ...

# %%
for i in ls():
    print(i)
# Out:
# .gitignore
# 01-21-2020_2200.csv
# 01-22-2020_1200.csv
# 01-23-2020_1200.csv
# 01-24-2020_0000.csv
# 01-24-2020_1200.csv
# 01-25-2020_0000.csv
# 01-25-2020_1200.csv
# 01-25-2020_2200.csv
# 01-26-2020_1100.csv
# 01-26-2020_2300.csv
# 01-27-2020_0900.csv
# 01-27-2020_1900.csv
# 01-27-2020_2030.csv
# 01-28-2020_1300.csv
# 01-28-2020_1800.csv
# 01-28-2020_2300.csv
# 01-29-2020_1330.csv
# 01-29-2020_1430.csv
# 01-29-2020_2100.csv
# 01-30-2020_1100.csv
# 01-30-2020_2130.csv
# 01-31-2020_1400.csv
# 02-01-2020_1000.csv
# 02-01-2020_1800.csv
# 02-01-2020_2300.csv
# 02-02-2020_0500.csv
# 02-02-2020_1945.csv
# 02-02-2020_2100.csv
# 02-03-2020_1230.csv
# 02-03-2020_2140.csv
# 02-04-2020_0800.csv
# 02-04-2020_1150.csv
# 02-04-2020_2200.csv
# 02-05-2020_1220.csv
# 02-06-2020_1318.csv
# 02-06-2020_2005.csv
# 02-07-2020_2024.csv
# 02-08-2020_1024.csv
# 02-08-2020_2304.csv
# 02-09-2020_1030.csv
# 02-09-2020_2320.csv
# 02-10-2020_1030.csv
# 02-10-2020_1930.csv
# 02-11-2020_1050.csv
# ...
