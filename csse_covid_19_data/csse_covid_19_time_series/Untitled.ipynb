# %%
import pandas as pd

# %%
data = pd.read_csv("time_series_covid19_confirmed_global.csv")

# %%
data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/17/20  3/18/20  3/19/20  3/20/20  \
# 0        0        0        0  ...       22       22       22       24
# 1        0        0        0  ...       55       59       64       70
# 2        0        0        0  ...       60       74       87       90
# 3        0        0        0  ...       39       39       53       75
# 4        0        0        0  ...        0        0        0        1
#
#    3/21/20  3/22/20  3/23/20  3/24/20  3/25/20  3/26/20
# ...

# %%
data_salida = data[["Province/State","Country/Region","Lat","Long"]]

# %%
columna_anterior = ""
for columna in data.columns[5:]:
    if(columna_anterior == ""):
        #print("no se hace nada")
        pass
    else:
        #print(columna + " y " + columna_anterior)
        data_salida[columna] = data[columna] - data[columna_anterior]
    columna_anterior = columna
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_salida.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  3/17/20  3/18/20  3/19/20  3/20/20  \
# 0        0        0        0  ...        1        0        0        2
# 1        0        0        0  ...        4        4        5        6
# 2        0        0        0  ...        6       14       13        3
# 3        0        0        0  ...       37        0       14       22
# 4        0        0        0  ...        0        0        0        1
#
#    3/21/20  3/22/20  3/23/20  3/24/20  3/25/20  3/26/20
# ...

# %%
data_salida.to_excel("NoAcumulado.xlsx", index = False)

# %%
data.to_excel("Acumulado.xlsx", index=False)

# %%
data_salida.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  3/17/20  3/18/20  3/19/20  3/20/20  \
# 0        0        0        0  ...        1        0        0        2
# 1        0        0        0  ...        4        4        5        6
# 2        0        0        0  ...        6       14       13        3
# 3        0        0        0  ...       37        0       14       22
# 4        0        0        0  ...        0        0        0        1
#
#    3/21/20  3/22/20  3/23/20  3/24/20  3/25/20  3/26/20
# ...

# %%
data3 = data_salida.append({"Province/State":None}, ignore_index=True)
data3.tail()
# Out:
#             Province/State         Country/Region        Lat        Long
# 244                    NaN  Saint Kitts and Nevis  17.357822  -62.782998
# 245  Northwest Territories                 Canada  64.825500 -124.845700
# 246                  Yukon                 Canada  64.282300 -135.000000
# 247                    NaN                 Kosovo  42.602636   20.902977
# 248                   None                    NaN        NaN         NaN

# %%
data4 = pd.DataFrame(columns=data_salida.columns[:4])
data4["numero"] = None
data4["fecha"] = None
data4.head()
#data_salida.head()
#data_salida
# Out:
# Empty DataFrame
# Columns: [Province/State, Country/Region, Lat, Long, numero, fecha]
# Index: []

# %%
data4 = pd.DataFrame(columns=data_salida.columns[:4])
data4["numero"] = None
data4["fecha"] = None
entrada = {"Province/State":""}   #,"Country/Region":"","Lat":"","Long":""}
salida = []


for i in data_salida.iterrows():
    #print(i[1]["Lat"])
    for columna in data_salida.columns[4:]:         
        #print(columna)
        #print(i[1][columna])
        entrada["Province/State"] = i[1]["Province/State"]
        entrada["Country/Region"] = i[1]["Country/Region"]
        entrada["Lat"] = i[1]["Lat"]
        entrada["Long"] = i[1]["Long"]
        entrada["fecha"] = columna
        entrada["numero"] = i[1][columna]
        print(entrada)
        #i[1]["fecha"] = columna
        #i[1]["numero"] = i[1][columna]
        #data4 = data4.append(i[1],ignore_index=True)
        #data4 = data4.append(entrada,ignore_index=True)
        salida.append(data4.append(entrada,ignore_index=True))
data4 = pd.concat(salida)
# Out:
# {'Province/State': nan, 'Country/Region': 'Afghanistan', 'Lat': 33.0, 'Long': 65.0, 'fecha': '1/24/20', 'numero': 0}
# {'Province/State': nan, 'Country/Region': 'Afghanistan', 'Lat': 33.0, 'Long': 65.0, 'fecha': '1/25/20', 'numero': 0}
# {'Province/State': nan, 'Country/Region': 'Afghanistan', 'Lat': 33.0, 'Long': 65.0, 'fecha': '1/26/20', 'numero': 0}
# {'Province/State': nan, 'Country/Region': 'Afghanistan', 'Lat': 33.0, 'Long': 65.0, 'fecha': '1/27/20', 'numero': 0}
# {'Province/State': nan, 'Country/Region': 'Afghanistan', 'Lat': 33.0, 'Long': 65.0, 'fecha': '1/28/20', 'numero': 0}
# {'Province/State': nan, 'Country/Region': 'Afghanistan', 'Lat': 33.0, 'Long': 65.0, 'fecha': '1/29/20', 'numero': 0}
# {'Province/State': nan, 'Country/Region': 'Afghanistan', 'Lat': 33.0, 'Long': 65.0, 'fecha': '1/30/20', 'numero': 0}
# {'Province/State': nan, 'Country/Region': 'Afghanistan', 'Lat': 33.0, 'Long': 65.0, 'fecha': '1/31/20', 'numero': 0}
# ...

# %%
#for columna in data_salida.columns[4:]:        
#        print(columna)
data4
# Out:
#    Province/State Country/Region        Lat       Long numero    fecha
# 0             NaN    Afghanistan  33.000000  65.000000      0  1/24/20
# 0             NaN    Afghanistan  33.000000  65.000000      0  1/25/20
# 0             NaN    Afghanistan  33.000000  65.000000      0  1/26/20
# 0             NaN    Afghanistan  33.000000  65.000000      0  1/27/20
# 0             NaN    Afghanistan  33.000000  65.000000      0  1/28/20
# ..            ...            ...        ...        ...    ...      ...
# 0             NaN         Kosovo  42.602636  20.902977      0  3/22/20
# 0             NaN         Kosovo  42.602636  20.902977      0  3/23/20
# 0             NaN         Kosovo  42.602636  20.902977      0  3/24/20
# 0             NaN         Kosovo  42.602636  20.902977      0  3/25/20
# 0             NaN         Kosovo  42.602636  20.902977     71  3/26/20
#
# [15624 rows x 6 columns]

# %%
data4
# Out:
#       Province/State Country/Region        Lat       Long 1/24/20 1/25/20  \
# 0                NaN    Afghanistan  33.000000  65.000000       0       0
# 1                NaN    Afghanistan  33.000000  65.000000       0       0
# 2                NaN    Afghanistan  33.000000  65.000000       0       0
# 3                NaN    Afghanistan  33.000000  65.000000       0       0
# 4                NaN    Afghanistan  33.000000  65.000000       0       0
# ...              ...            ...        ...        ...     ...     ...
# 15619            NaN         Kosovo  42.602636  20.902977       0       0
# 15620            NaN         Kosovo  42.602636  20.902977       0       0
# 15621            NaN         Kosovo  42.602636  20.902977       0       0
# 15622            NaN         Kosovo  42.602636  20.902977       0       0
# 15623            NaN         Kosovo  42.602636  20.902977       0       0
#
#       1/26/20 1/27/20 1/28/20 1/29/20  ... 3/19/20 3/20/20 3/21/20 3/22/20  \
# ...

# %%
data4.to_excel("test.xlsx", index=False)

# %%
data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/17/20  3/18/20  3/19/20  3/20/20  \
# 0        0        0        0  ...       22       22       22       24
# 1        0        0        0  ...       55       59       64       70
# 2        0        0        0  ...       60       74       87       90
# 3        0        0        0  ...       39       39       53       75
# 4        0        0        0  ...        0        0        0        1
#
#    3/21/20  3/22/20  3/23/20  3/24/20  3/25/20  3/26/20
# ...

# %%
data.iterrows()[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-8f5420756715> in <module>
# ----> 1 data.iterrows()[1]
#
# TypeError: 'generator' object is not subscriptable

# %%
lista = list(data.iterrows())

# %%
len(lista)
# Out:
# 248

# %%
lista[1][1]["3/22/20"]
# Out:
# 89
