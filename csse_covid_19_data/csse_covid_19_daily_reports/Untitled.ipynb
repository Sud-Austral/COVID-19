# %%
import pandas as pd

# %%
data = pd.read_csv("Export_Output.txt", sep=";")

# %%
data.head()
# Out:
#          NAME         COUNTRY  \
# 0      Jersey          Jersey
# 1    Vysocina  Czech Republic
# 2    Kanagawa           Japan
# 3  Nei Mongol           China
# 4       Herat     Afghanistan
#
#                                             ISO_CODE ISO_CC  \
# 0                                                 JE     JE
# 1       https://onemocneni-aktualne.mzcr.cz/covid-19     CZ
# 2  https://www3.nhk.or.jp/news/html/20200304/k100...     JP
# 3  https://3g.dxy.cn/newh5/view/pneumonia?scene=2...     CN
# 4  https://ariananews.af/two-new-covid-19-cases-t...     AF
#
#            ADMINTYPE      COUNTRYAFF CONTINENT     LAND_TYPE  \
# 0   Crown Dependency  United Kingdom    Europe  Small island
# 1             Region  Czech Republic    Europe  Primary land
# 2         Prefecture           Japan      Asia  Primary land
# 3  Autonomous Region           China      Asia  Primary land
# 4           Province     Afghanistan      Asia  Primary land
#
# ...

# %%
data.to_csv("Alert1.csv", index=False)

# %%
data = pd.read_csv("Alert1.csv")

# %%
data.head()
# Out:
#          NAME         COUNTRY  \
# 0      Jersey          Jersey
# 1    Vysocina  Czech Republic
# 2    Kanagawa           Japan
# 3  Nei Mongol           China
# 4       Herat     Afghanistan
#
#                                             ISO_CODE ISO_CC  \
# 0                                                 JE     JE
# 1       https://onemocneni-aktualne.mzcr.cz/covid-19     CZ
# 2  https://www3.nhk.or.jp/news/html/20200304/k100...     JP
# 3  https://3g.dxy.cn/newh5/view/pneumonia?scene=2...     CN
# 4  https://ariananews.af/two-new-covid-19-cases-t...     AF
#
#            ADMINTYPE      COUNTRYAFF CONTINENT     LAND_TYPE  \
# 0   Crown Dependency  United Kingdom    Europe  Small island
# 1             Region  Czech Republic    Europe  Primary land
# 2         Prefecture           Japan      Asia  Primary land
# 3  Autonomous Region           China      Asia  Primary land
# 4           Province     Afghanistan      Asia  Primary land
#
# ...

# %%
data[data["COUNTRY"]]
